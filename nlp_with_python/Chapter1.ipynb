# %% [markdown]
# # 1

# %%
12 / (4 + 1)
# Out:
# 2.4

# %% [markdown]
# # 2

# %%
26**100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# # 3

# %%
['Monty', 'Python'] * 20
# Out:
# ['Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python']

# %%
sent1 = ['Call', 'me', 'Ishmael', 'Some']
3 * sent1
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  'Some',
#  'Call',
#  'me',
#  'Ishmael',
#  'Some',
#  'Call',
#  'me',
#  'Ishmael',
#  'Some']

# %% [markdown]
# # 4

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
len(text2), len(set(text2))
# Out:
# (141576, 6833)

# %% [markdown]
# ## 5

# %% [markdown]
# - ユーモアの語彙の多様性は4.3
# - ロマンスの語彙の多様性は8.3
#
# よってユーモアとロマンスでは、ロマンスの方が語彙の多様性がある。

# %% [markdown]
# ## 6

# %%
# %matplotlib inline
text2.dispersion_plot(['Elinor', 'Marianne', 'Edward', 'Willoughby'])

# %% [markdown]
# 女性は一貫して出て来やすいが男性はまばらである。ここからカップルを見つけることは難しい。

# %% [markdown]
# ## 7

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# ## 8

# %% [markdown]
# len(set(text4))の目的は、単語のユニーク数をカウントすることである。set関数で語彙をユニークにして、len関数でそれを数える。

# %% [markdown]
# ## 9

# %%
xxx = "xxxxxx"
print(xxx)
xxx
# Out:
# xxxxxx
# 'xxxxxx'

# %%
xxx + xxx
# Out:
# 'xxxxxxxxxxxx'

# %%
xxx * 3
# Out:
# 'xxxxxxxxxxxxxxxxxx'

# %%
' '.join([xxx for i in range(3)])
# Out:
# 'xxxxxx xxxxxx xxxxxx'

# %% [markdown]
# ## 10

# %%
my_sent = ['my', 'sent']
my_sent_join = ' '.join(my_sent)
print(my_sent_join)
print(my_sent_join.split())
# Out:
# my sent
# ['my', 'sent']

# %% [markdown]
# ## 11

# %%
phrase1 = 'Hello world'
phrase2 = 'Hello work'
print(len(phrase1 + phrase2))
print(len(phrase1) + len(phrase2))
# Out:
# 21
# 21

# %% [markdown]
# ## 12

# %%
print("Monty Python"[6:12])
print(["Monty", "Python"][1])

# 後者は単語単位で扱ってるのでNLPと関連が強い
# Out:
# Python
# Python

# %% [markdown]
# ## 13

# %%
sent = ["Monty", "Python"]
sent[1][2]

# リストの1番目の単語を取り出し、その単語の2番目の文字を抽出している
# Out:
# 't'

# %% [markdown]
# ## 14

# %%
sent3.count('the')
# Out:
# 3

# %% [markdown]
# ## 15

# %%
sorted([ x for x in text5 if x.startswith('b')])
# Out:
# ['b',
#  'b',
#  'b',
#  'b',
#  'b',
#  'b',
#  'b-day',
#  'b/c',
#  'b4',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babe',
#  'babes',
#  'babes',
#  'babes',
#  'babi',
#  'babi',
#  'babies',
#  'babies',
#  'babiess',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
#  'back',
# ...

# %% [markdown]
# ## 16

# %%
range(10)
range(10, 20)
range(20, 10, -2)
# Out:
# range(20, 10, -2)

# %% [markdown]
# ## 17

# %%
sunset_pos = text9.index('sunset')
preiod_pos = text9[sunset_pos:].index('.') + sunset_pos + 1
start_pos = [i for (i, x) in enumerate(text9[:sunset_pos:-1]) if x.isupper()][0]
print(text9[sunset_pos-start_pos-1:preiod_pos])
# Out:
# ['THE', 'suburb', 'of', 'Saffron', 'Park', 'lay', 'on', 'the', 'sunset', 'side', 'of', 'London', ',', 'as', 'red', 'and', 'ragged', 'as', 'a', 'cloud', 'of', 'sunset', '.']

# %% [markdown]
# ## 18

# %%
all_words = sent1 + sent2 + sent3 + sent4 + sent5 + sent6 + sent7 + sent8
all_voca = set(all_words)
len(all_voca)
# Out:
# 75

# %% [markdown]
# ## 19

# %%
len(list(set([w.lower for w in text1])))
# Out:
# 212945

# %%
len(list([w.lower for w in set(text1)]))
# Out:
# 19317

# %% [markdown]
# ## 20

# %% [markdown]
# 前者は全てが大文字であればTrueになるのに対して、後者は一文字でも大文字があればTrueになる。

# %% [markdown]
# ## 21

# %%
text2[-2:]
# Out:
# ['THE', 'END']

# %% [markdown]
# ## 22

# %%
fdist = FreqDist(text5)
sorted([(fdist[w], w) for w in set(text5) if len(w) == 4], reverse=True)
# Out:
# [(1021, 'JOIN'),
#  (1016, 'PART'),
#  (274, 'that'),
#  (183, 'what'),
#  (181, 'here'),
#  (170, '....'),
#  (164, 'have'),
#  (156, 'like'),
#  (152, 'with'),
#  (142, 'chat'),
#  (137, 'your'),
#  (130, 'good'),
#  (125, 'just'),
#  (107, 'lmao'),
#  (103, 'know'),
#  (98, 'room'),
#  (92, 'from'),
#  (86, 'this'),
#  (81, 'well'),
#  (78, 'hiya'),
#  (78, 'back'),
#  (77, 'they'),
#  (75, 'yeah'),
#  (75, 'dont'),
#  (71, 'want'),
#  (60, 'love'),
#  (58, 'some'),
#  (58, 'guys'),
#  (57, 'been'),
#  (56, 'talk'),
#  (52, 'nice'),
#  (50, 'time'),
#  (48, 'when'),
#  (44, 'make'),
#  (44, 'haha'),
#  (43, 'need'),
#  (43, 'girl'),
#  (42, 'U122'),
#  (41, 'MODE'),
#  (40, 'will'),
#  (40, 'then'),
#  (40, 'much'),
#  (39, 'over'),
#  (38, 'work'),
#  (38, 'were'),
#  (37, 'take'),
#  (36, 'song'),
#  (36, 'U121'),
#  (36, 'U115'),
#  (35, 'seen'),
#  (35, 'even'),
#  (35, 'does'),
#  (35, 'U156'),
#  (35, 'U105'),
#  (34, 'more'),
#  (34, 'damn'),
#  (33, 'only'),
# ...

# %% [markdown]
# ## 23

# %%
[print(w) for w in text6 if w.isupper()]
# Out:
# SCENE
# KING
# ARTHUR
# SOLDIER
# ARTHUR
# I
# SOLDIER
# ARTHUR
# I
# I
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# I
# ARTHUR
# I
# SOLDIER
# SOLDIER
# SOLDIER
# I
# ARTHUR
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SCENE
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# SCENE
# ARTHUR
# DENNIS
# ...

# %% [markdown]
# ## 24

# %%
list(filter(lambda x: x.endswith('ize'), text6.vocab().keys()))
# Out:
# []

# %%
list(filter(lambda x: 'z' in x, text6.vocab().keys()))
# Out:
# ['zhiv', 'zoo', 'zone', 'zoop', 'Fetchez', 'frozen', 'zoosh', 'amazes']

# %%
list(filter(lambda x: 'pt' in x, text6.vocab().keys()))
# Out:
# ['ptoo',
#  'Thppt',
#  'temptress',
#  'excepting',
#  'Thpppt',
#  'empty',
#  'Chapter',
#  'aptly',
#  'Thppppt',
#  'temptation',
#  'Thpppppt']

# %%
def is_title_case(word):
    if not word[0].isupper():
        return False
    return all(c.islower() for c in word[1:])
    

list(filter(lambda x: is_title_case(x), text6.vocab().keys()))
# Out:
# ['If',
#  'Iiiiives',
#  'Steady',
#  'Tall',
#  'With',
#  'Twenty',
#  'Like',
#  'Ahh',
#  'First',
#  'Dis',
#  'Tell',
#  'Maynard',
#  'Action',
#  'Dennis',
#  'Huy',
#  'Never',
#  'Angnor',
#  'Halt',
#  'Ow',
#  'Three',
#  'Thppt',
#  'To',
#  'There',
#  'Does',
#  'Anthrax',
#  'Rather',
#  'Iesu',
#  'So',
#  'Hand',
#  'Nay',
#  'Now',
#  'Attila',
#  'Bread',
#  'Shh',
#  'Aaauggh',
#  'Make',
#  'Churches',
#  'Spring',
#  'Peril',
#  'Ayy',
#  'Am',
#  'By',
#  'Summer',
#  'Speak',
#  'Anarcho',
#  'Hee',
#  'Shut',
#  'Eee',
#  'Skip',
#  'Robin',
#  'Amen',
#  'Open',
#  'Supposing',
#  'Yay',
#  'Uhh',
#  'Behold',
#  'Brave',
#  'Hyy',
#  'Cherries',
#  'Thou',
#  'Ha',
#  'Guy',
#  'Oooh',
#  'Remove',
#  'Neee',
#  'Until',
#  'Launcelot',
#  'My',
#  'Olfin',
#  'Must',
#  'Stand',
#  'Arthur',
#  'Bedwere',
#  'Robinson',
#  'Hey',
#  'Please',
#  'Providence',
#  'Once',
#  'Hello',
#  'Swamp',
#  'Stop',
#  'Chop',
#  'Tale',
#  'Apples',
#  'Surely',
# ...

# %% [markdown]
# # 25

# %%
words = ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']

# %%
for word in filter(lambda x: x.startswith('sh'), words):
    print(word)
# Out:
# she
# shells
# shore

# %%
for word in filter(lambda x: len(x) > 4, words):
    print(word)
# Out:
# sells
# shells
# shore

# %% [markdown]
# # 26
# そのコードは、text1の単語の単語長の合計を計算する処理を行う。この数を単語数で割ることでtext1の平均単語長を求めることができる

# %% [markdown]
# # 27

# %%
def vocab_size(text):
    return len(set(text))

# %% [markdown]
# # 28

# %%
def percent(word, text):
    return text.count(word) / len(text)
